# %% [markdown]
# # Notebooks #
# Notebook is a specialfile (usually .ipynb) that lets you:
# + Write code
# + Run code
# + See output
# + Add notes, equations, images, charts - all in one place.
#
# > Now one of the most popular notebooks are Jupyter notebook. We download this using Anaconda.

# %% [markdown]
# # Numpy #
# Array couldn't support in python. So numpy is  created .Numpy is 50x faster than python list.
